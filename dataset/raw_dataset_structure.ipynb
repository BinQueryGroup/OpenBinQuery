# %%
from datasets import load_from_disk
from pprint import pprint
from loguru import logger
from pathlib import Path
import pickle
import random
import zstd

# %% [markdown]
# We delete the output of the block above, as it will output a warning prompt containing identity information.

# %%
def decompress_data(b_str):
    return pickle.loads(zstd.decompress(b_str))
def compress_data(obj):
    return zstd.compress(pickle.dumps(obj))

# %%
ds = load_from_disk("data/raw")

# %%
example_row = random.choice(ds)

# %%
asm = decompress_data(example_row["asm"])
source_code = example_row["source_code"]
addr_to_source_code_file_line = decompress_data(example_row["addr_to_source_code_file_line"])

# %%
print("asm_code:")
for line, code_row in enumerate(asm["code"]):
    print(f"asm_line {line}: {code_row}")
# Out:
# asm_code:
# asm_line 0: ['endbr64']
# asm_line 1: ['sub', 'rsp', '8']
# asm_line 2: ['mov', 'r10', 'rsi']
# asm_line 3: ['mov', 'r11d', '[rsp+8+arg_0]']
# asm_line 4: ['mov', 'eax', '[rsp+8+arg_8]']
# asm_line 5: ['mov', 'esi', '[rsp+8+arg_10]']
# asm_line 6: ['test', 'rcx', 'rcx']
# asm_line 7: ['jz', 'loc_A4730']
# asm_line 8: ['test', 'r9d', 'r9d']
# asm_line 9: ['jle', 'loc_A46F8']
# asm_line 10: ['test', 'r11d', 'r11d']
# asm_line 11: ['jle', 'loc_A4710']
# asm_line 12: ['cmp', 'r9d', 'r11d']
# asm_line 13: ['jg', 'loc_A46D0']
# asm_line 14: ['mov', '[rsp+8+arg_10]', 'esi']
# asm_line 15: ['mov', 'rsi', 'r10']
# asm_line 16: ['mov', '[rsp+8+arg_8]', 'eax']
# asm_line 17: ['mov', '[rsp+8+arg_0]', 'r11d']
# asm_line 18: ['add', 'rsp', '8']
# asm_line 19: ['jmp', 'sub_9C100']
# asm_line 20: ['mov', 'ecx', 'r11d']
# asm_line 21: ['mov', 'edx', 'r9d']
# asm_line 22: ['lea', 'rsi', 'aCp9Hmm2ijbands_2']
# asm_line 23: ['mov', 'rdi', 'r10']
# asm_line 24: ['xor', 'eax', 'eax']
# asm_line 25: ['call', 'sub_1A7E30']
# asm_line 26: ['mov', 'eax', '0Ah']
# asm_line 27: ['add', 'rsp', '8']
# asm_line 28: ['retn']
# asm_line 29: ['mov', 'edx', 'r9d']
# asm_line 30: ['lea', 'rsi', 'aCp9Hmm2ijbands_3']
# asm_line 31: ['mov', 'rdi', 'r10']
# asm_line 32: ['xor', 'eax', 'eax']
# asm_line 33: ['call', 'sub_1A7E30']
# asm_line 34: ['jmp', 'loc_A46E7']
# asm_line 35: ['mov', 'edx', 'r11d']
# asm_line 36: ['lea', 'rsi', 'aCp9Hmm2ijbands_4']
# asm_line 37: ['mov', 'rdi', 'r10']
# asm_line 38: ['xor', 'eax', 'eax']
# asm_line 39: ['call', 'sub_1A7E30']
# asm_line 40: ['jmp', 'loc_A46E7']
# asm_line 41: ['lea', 'rsi', 'aCp9Hmm2ijbands_5']
# asm_line 42: ['mov', 'rdi', 'r10']
# asm_line 43: ['xor', 'eax', 'eax']
# asm_line 44: ['call', 'sub_1A7E30']
# asm_line 45: ['jmp', 'loc_A46E7']

# %%
print("Addr to asm code line map:")
for k, v in asm['anchor_map'].items():
    print(f"{hex(k)}: asm_line {v}")
# Out:
# Addr to asm code line map:
# 0xa4688: asm_line 2
# 0xa468b: asm_line 3
# 0xa4690: asm_line 4
# 0xa4694: asm_line 5
# 0xa4698: asm_line 6
# 0xa469b: asm_line 7
# 0xa46a1: asm_line 8
# 0xa46a4: asm_line 9
# 0xa46a6: asm_line 10
# 0xa46a9: asm_line 11
# 0xa46ab: asm_line 12
# 0xa46ae: asm_line 13
# 0xa46b4: asm_line 15
# 0xa46b7: asm_line 16
# 0xa46bb: asm_line 17
# 0xa46d0: asm_line 20
# 0xa46d3: asm_line 21
# 0xa46d6: asm_line 22
# 0xa46dd: asm_line 23
# 0xa46e0: asm_line 24
# 0xa46e2: asm_line 25
# 0xa46f8: asm_line 29
# 0xa46fb: asm_line 30
# 0xa4702: asm_line 31
# 0xa4705: asm_line 32
# 0xa4707: asm_line 33
# 0xa470c: asm_line 34
# 0xa4710: asm_line 35
# 0xa4713: asm_line 36
# 0xa471a: asm_line 37
# 0xa471d: asm_line 38
# 0xa471f: asm_line 39
# 0xa4724: asm_line 40
# 0xa4730: asm_line 41
# 0xa4737: asm_line 42
# 0xa473a: asm_line 43
# 0xa473c: asm_line 44
# 0xa4741: asm_line 45

# %% [markdown]
# In the `anchor_map` above, we only recorded the assembly code addresses corresponding to the source code line numbers, which will serve as the basis for extracting binary code snippets in the future.

# %%
print("source_code:")
source_lines = source_code.split("\n")
for lino, code_line in enumerate(source_lines):
    print(f"source_line {lino + addr_to_source_code_file_line['line'][0]}: {code_line}")
# Out:
# source_code:
# source_line 1519: int
# source_line 1520: cp9_HMM2ijBands(CM_t *cm, char *errbuf, CP9_t *cp9, CP9Bands_t *cp9b, CP9Map_t *cp9map, int i0, int j0, int doing_search, int do_trunc, int debug_level)
# source_line 1521: {
# source_line 1522:
# source_line 1523:   int status;
# source_line 1524:   int v;
# source_line 1525:
# source_line 1526:   /* ptrs to cp9b data, for convenience */
# source_line 1527:   int *imin;          /* imin[v] = first position in band on i for state v to be filled in this function. [1..M] */
# source_line 1528:   int *imax;          /* imax[v] = last position in band on i for state v to be filled in this function. [1..M] */
# source_line 1529:   int *jmin;          /* jmin[v] = first position in band on j for state v to be filled in this function. [1..M] */
# source_line 1530:   int *jmax;          /* jmax[v] = last position in band on j for state v to be filled in this function. [1..M] */
# source_line 1531:
# source_line 1532:   int nd;                  /* counter over CM nodes. */
# source_line 1533:   int y;                   /* counters over children states */
# source_line 1534:   int hmm_M;               /* number of nodes in the HMM */
# source_line 1535:   ESL_STACK   *nd_pda;     /* used to traverse the CM from left to right in consensus positions, cpos = 0..clen */
# source_line 1536:   ESL_STACK   *lpos_pda;   /* used to store lpos for BIF nodes */
# source_line 1537:   int          on_right;   /* TRUE if we're on the right for current node during our CM traversal */
# source_line 1538:   int          w;          /* a state index */
# source_line 1539:   int          lpos, rpos; /* left/right border of subtree for current node */
# source_line 1540:   /*int          k;*/          /* counter of HMM nodes, for debugging print statements, currently not used */
# source_line 1541:   int hmm_is_localized;      /* TRUE if HMM has local begins, ends or ELs on */
# source_line 1542:   int cm_is_fully_localized; /* TRUE if CM has local begins and ends on */
# source_line 1543:
# source_line 1544:   /* r_* arrays, these are filled in HMMBandsEnforceValidParse(), they are the band on 'reachable'
# source_line 1545:    * residues for each HMM state as we move from left to right through the HMM.
# source_line 1546:    * For example, r_mn[k] = 3, r_mx[k] = 5, means that for all possible HMM parses within the bands
# source_line 1547:    * in the cp9b pn_* arrays that reach the match state of node k, the residue emitted by that match
# source_line 1548:    * must be either 3, 4, or 5.
# source_line 1549:    */
# source_line 1550:   int *r_mn;   /* [0..k..hmm_M] minimal residue position for which we can reach M_k (match state of node k) */
# source_line 1551:   int *r_mx;   /* [0..k..hmm_M] maximal residue position for which we can reach M_k */
# source_line 1552:   int *r_in;   /* [0..k..hmm_M] minimal residue position for which we can reach I_k (insert state of node k) */
# source_line 1553:   int *r_ix;   /* [0..k..hmm_M] maximal residue position for which we can reach I_k */
# source_line 1554:   int *r_dn;   /* [0..k..hmm_M] minimal residue position for which we can reach D_k (delete state of node k) */
# source_line 1555:   int *r_dx;   /* [0..k..hmm_M] maximal residue position for which we can reach D_k */
# source_line 1556:   int *r_nn_i; /* [0..k..hmm_M] minimal residue position for which we can reach node k (any of M_k, I_k, D_k) */
# source_line 1557:   int *r_nx_i; /* [0..k..hmm_M] maximal residue position for which we can reach node k (any of M_k, I_k, D_k) */
# source_line 1558:   int *r_nn_j; /* [0..k..hmm_M] minimal residue position for which we can reach node k (any of M_k, I_k, D_k) */
# source_line 1559:   int *r_nx_j; /* [0..k..hmm_M] maximal residue position for which we can reach node k (any of M_k, I_k, D_k) */
# source_line 1560:   /* r_nn_i and r_nx_i are used when setting i bands, and r_nn_j and r_nx_j are used when setting j bands .
# source_line 1561:    * the values can differ vecause of an off-by-one issue with the non-emitting (delete and M_0) states of the HMM:
# source_line 1562:    * pn_min_d[k] = i, means posn i was last residue emitted prior to entering node k's delete state. However, for a CM,
# source_line 1563:    * if a delete states sub-parsetree is bounded by i' and j', this means positions i' and j' HAVE YET TO BE EMITTED.
# source_line 1564:    * For i states this means we have to add 1 to the delete band positions, but for j states we do not, the off-by-one
# source_line 1565:    * is taken care of because the HMM is moving left to right, while j positions move right to left (confusing as hell,
# source_line 1566:    * bad explanation, i know... write out an example, its the only way to get it).
# source_line 1567:    */
# source_line 1568:
# source_line 1569:   /* Contract checks */
# source_line 1570:   if (cp9b == NULL)                                                                   ESL_FAIL(eslEINCOMPAT, errbuf, "cp9_HMM2ijBands(), cp9b is NULL.\n");
# source_line 1571:   if(i0 < 1) ESL_FAIL(eslEINCOMPAT,  errbuf, "cp9_HMM2ijBands(), i0 < 1: %d\n", i0);
# source_line 1572:   if(j0 < 1) ESL_FAIL(eslEINCOMPAT,  errbuf, "cp9_HMM2ijBands(), j0 < 1: %d\n", j0);
# source_line 1573:   if(j0 < i0) ESL_FAIL(eslEINCOMPAT, errbuf, "cp9_HMM2ijBands(), i0 (%d) < j0 (%d)\n", i0, j0);
# source_line 1574:   hmm_is_localized      = ((cp9->flags & CPLAN9_LOCAL_BEGIN) || (cp9->flags & CPLAN9_LOCAL_END) || (cp9->flags & CPLAN9_EL)) ? TRUE : FALSE;
# source_line 1575:   cm_is_fully_localized = ((cm->flags & CMH_LOCAL_BEGIN) && (cm->flags & CMH_LOCAL_END)) ? TRUE : FALSE;
# source_line 1576:
# source_line 1577:   /* ptrs to cp9b arrays, for convenience */
# source_line 1578:   imin     = cp9b->imin;
# source_line 1579:   imax     = cp9b->imax;
# source_line 1580:   jmin     = cp9b->jmin;
# source_line 1581:   jmax     = cp9b->jmax;
# source_line 1582:   hmm_M    = cp9b->hmm_M;
# source_line 1583:   /* Initialize all bands to -1 */
# source_line 1584:   esl_vec_ISet(imin, cm->M, -1);
# source_line 1585:   esl_vec_ISet(imax, cm->M, -2);
# source_line 1586:   esl_vec_ISet(jmin, cm->M, -1);
# source_line 1587:   esl_vec_ISet(jmax, cm->M, -2);
# source_line 1588:
# source_line 1589:   /* Step 1: Check for valid HMM parse within the HMM bands, if there isn't one messily expand the bands so that there is one */
# source_line 1590:   if((status = HMMBandsEnforceValidParse(cp9, cp9b, cp9map, errbuf, i0, j0, doing_search, NULL,
# source_line 1591: 					 &r_mn, &r_mx, &r_in, &r_ix, &r_dn, &r_dx, &r_nn_i, &r_nx_i, &r_nn_j, &r_nx_j)) != eslOK) return status;
# source_line 1592:
# source_line 1593:   /* debugging printf block */
# source_line 1594:   /*
# source_line 1595:     for(k = 0; k <= cp9b->hmm_M;k ++) {
# source_line 1596:     printf("k: %4d  %4d %4d  %4d %4d  %4d %4d  %4d %4d  %4d  %4d\n", k, r_mn[k], r_mx[k], r_in[k], r_ix[k], r_dn[k], r_dx[k], r_nn_i[k], r_nx_i[k], r_nn_j[k], r_nx_j[k]);
# source_line 1597:     }
# source_line 1598:     cp9_DebugPrintHMMBands(stdout, j0, cp9b, cm->tau, 1);
# source_line 1599:   */
# source_line 1600:
# source_line 1601:   /* Step 2: Traverse the CM from left to right in consensus position coordinates. Fill in the
# source_line 1602:    *         i and j bands (imin, imax, jmin, jmax) for all states as we go. The CM is traversed
# source_line 1603:    *         using a stack, each node is visited twice (this is based on Sean's cleaner:
# source_line 1604:    *         display.c::CreateEmitMap(). The first time a node <nd> is visited we're 'on the left'
# source_line 1605:    *         and then we push it back to the stack, and visit it again 'on the right' later. We
# source_line 1606:    *         are moving around the perimeter of the guide tree, stepping one position at a time
# source_line 1607:    *         in the consensus sequence coordinates, from left to right. We mainly set bands
# source_line 1608:    *         when we're 'on the right', with the exception of Left emitting states, which are
# source_line 1609:    *         set when we're on the HMM. All emitting states and delete states v have either
# source_line 1610:    *         i, or j or both bands that can be set 'explicitly' based on the HMM bands for
# source_line 1611:    *         the HMM state that maps to v. For example we can set the i bands for MATL_ML
# source_line 1612:    *         states, and the j bands for MATR_MR states. All other bands (and both i
# source_line 1613:    *         and j bands for S states, B states, E states) are set 'implicitly based on the
# source_line 1614:    *         explicit bands, and the r_* data structures we filled in HMMBandsEnforceValidParse().
# source_line 1615:    *         The goal was to make this function as clean and simple as possible, and although
# source_line 1616:    *         it doesn't look it, this is as good as I can get it. There are many special
# source_line 1617:    *         cases that make an elegant implementation beyond me.
# source_line 1618:    */
# source_line 1619:   if(! doing_search) {
# source_line 1620:     assert(r_mn[0] == (i0-1));
# source_line 1621:     if(!hmm_is_localized) assert(r_mx[hmm_M] == j0 || r_ix[hmm_M] == j0 || r_dx[hmm_M] == j0);
# source_line 1622:   }
# source_line 1623:   nd   = 0;
# source_line 1624:   lpos = 0;
# source_line 1625:   rpos = 0;
# source_line 1626:
# source_line 1627:   if ((nd_pda    = esl_stack_ICreate())      == NULL)  goto ERROR;
# source_line 1628:   if ((lpos_pda  = esl_stack_ICreate())      == NULL)  goto ERROR;
# source_line 1629:   if ((status = esl_stack_IPush(nd_pda, 0))  != eslOK) goto ERROR;		/* 0 = left side. 1 would = right side. */
# source_line 1630:   if ((status = esl_stack_IPush(nd_pda, nd)) != eslOK) goto ERROR;
# source_line 1631:   while (esl_stack_IPop(nd_pda, &nd) != eslEOD)
# source_line 1632:     {
# source_line 1633:       esl_stack_IPop(nd_pda, &on_right);
# source_line 1634:       if (on_right) {
# source_line 1635: 	switch(cm->ndtype[nd]) { /* this is a massive switch, we set i and j bands for almost all
# source_line 1636: 				  * states here when we're on the right (sole exceptions are i bands for
# source_line 1637: 				  * MATP_nd states (except MATP_IR), and MATL_nd states) */
# source_line 1638:
# source_line 1639: 	case BIF_nd: /* special case, set i bands based on left child, j bands based on right child */
# source_line 1640: 	  v = cm->nodemap[nd];
# source_line 1641: 	  w = cm->cfirst[v]; /* BEGL_S */
# source_line 1642: 	  y = cm->cnum[v];   /* BEGR_S */
# source_line 1643:
# source_line 1644: 	  /* set v's i band based on left child w, and v's j band based on right child y */
# source_line 1645: 	  imin[v] = (imin[w] != -1) ? imin[w] : imin[y]; /* if imin[w] == imin[y] == -1, then imin[v] will be set as -1 */
# source_line 1646: 	  imax[v] = (imax[w] != -2) ? imax[w] : imax[y]; /* if imax[w] == imax[y] == -2, then imax[v] will be set as -2 */
# source_line 1647: 	  jmin[v] = (jmin[y] != -1) ? jmin[y] : jmin[w]; /* if jmin[y] == jmin[w] == -1, then jmin[v] will be set as -1 */
# source_line 1648: 	  jmax[v] = (jmax[y] != -2) ? jmax[y] : jmax[w]; /* if jmax[y] == jmax[w] == -2, then jmax[v] will be set as -2 */
# source_line 1649:
# source_line 1650: 	  if(! do_trunc) {
# source_line 1651: 	    /* check for possibility that either child is not reachable, will only possibly happen with local on */
# source_line 1652: 	    if(imin[w] == -1 || jmin[w] == -1 || imin[y] == -1 || jmin[y] == -1 ||
# source_line 1653: 	       imax[w] == -2 || imax[w] == -2 || jmax[y] == -2 || jmax[y] == -2) {
# source_line 1654: 	      /* either the left child, or right child is not reachable, make them both unreachable as well as the BIF state */
# source_line 1655: 	      imin[v] = imin[w] = imin[y] = jmin[v] = jmin[w] = jmin[y] = -1;
# source_line 1656: 	      imax[v] = imax[w] = imax[y] = jmax[v] = jmax[w] = jmax[y] = -2;
# source_line 1657: 	      /* also make the BEGR_IL unreachable */
# source_line 1658: 	      imin[y+1] = jmin[y+1] = -1;
# source_line 1659: 	      imax[y+1] = jmax[y+1] = -2;
# source_line 1660: 	    }
# source_line 1661: 	  }
# source_line 1662: 	  break;
# source_line 1663:
# source_line 1664: 	case MATP_nd:
# source_line 1665: 	  lpos = cp9map->nd2lpos[nd];
# source_line 1666: 	  rpos = cp9map->nd2rpos[nd];
# source_line 1667:
# source_line 1668: 	  v = cm->nodemap[nd]; /* v is MATP_MP */
# source_line 1669: 	  jmin[v] = r_mn[rpos];
# source_line 1670: 	  jmax[v] = r_mx[rpos];
# source_line 1671:
# source_line 1672: 	  v++; /* v is MATP_ML */
# source_line 1673: 	  jmin[v] = r_dn[rpos];
# source_line 1674: 	  jmax[v] = r_dx[rpos];
# source_line 1675:
# source_line 1676: 	  v++; /* v is MATP_MR */
# source_line 1677: 	  jmin[v] = r_mn[rpos];
# source_line 1678: 	  jmax[v] = r_mx[rpos];
# source_line 1679:
# source_line 1680: 	  v++; /* v is MATP_D */
# source_line 1681: 	  jmin[v] = r_dn[rpos];
# source_line 1682: 	  jmax[v] = r_dx[rpos];
# source_line 1683:
# source_line 1684: 	  v++; /* v is MATP_IL */
# source_line 1685: 	  jmin[v] = r_nn_j[rpos-1];
# source_line 1686: 	  jmax[v] = r_nx_j[rpos-1];
# source_line 1687:
# source_line 1688: 	  v++; /* v is MATP_IR */
# source_line 1689: 	  jmin[v] = r_in[rpos-1];
# source_line 1690: 	  jmax[v] = r_ix[rpos-1];
# source_line 1691: 	  imin[v] = r_nn_i[lpos+1]; /* look at band on lpos *+1* b/c we enter MATP_IR AFTER the MATP_MP, MATP_MR, MATP_ML, or MATP_IL insert (if any) */
# source_line 1692: 	  imax[v] = r_nx_i[lpos+1]; /* look at band on lpos *+1* b/c we enter MATP_IR AFTER the MATP_MP, MATP_MR, MATP_ML, or MATP_IL insert (if any) */
# source_line 1693: 	  ESL_DASSERT1(((lpos+1) <= cm->clen)); /* note: we know lpos+1 <= cm->clen b/c we're in a MATP node, and the ccol the right half of the node maps to
# source_line 1694: 						 *       must be to the right of the ccol the left half of the node maps to */
# source_line 1695: 	  if(imin[v] == 0) { cm_Fail("v: %d lpos: %d\n", v, lpos); }
# source_line 1696: 	  break; /* case MATP_nd */
# source_line 1697:
# source_line 1698:        	case MATL_nd: /* i bands were set when we were on the left, non-right emitter, set implicit j bands */
# source_line 1699: 	  lpos = cp9map->nd2lpos[nd];
# source_line 1700:
# source_line 1701: 	  v = cm->nodemap[nd]; /* v is MATL_ML */
# source_line 1702: 	  jmin[v] = r_nn_j[rpos];
# source_line 1703: 	  jmax[v] = r_nx_j[rpos];
# source_line 1704:
# source_line 1705: 	  v++; /* v is MATL_D, the MATL_ML and MATL_IL concerns don't apply, D's don't emit */
# source_line 1706: 	  jmin[v] = r_nn_j[rpos];
# source_line 1707: 	  jmax[v] = r_nx_j[rpos];
# source_line 1708:
# source_line 1709: 	  v++; /* v is MATL_IL */
# source_line 1710: 	  jmin[v] = r_nn_j[rpos];
# source_line 1711: 	  jmax[v] = r_nx_j[rpos];
# source_line 1712: 	  break;
# source_line 1713:
# source_line 1714: 	case MATR_nd: /* set j bands explicitly from HMM bands, i bands implicitly */
# source_line 1715: 	  rpos = cp9map->nd2rpos[nd];
# source_line 1716: 	  v = cm->nodemap[nd]; /* v is MATR_MR */
# source_line 1717: 	  jmin[v] = r_mn[rpos];
# source_line 1718: 	  jmax[v] = r_mx[rpos];
# source_line 1719: 	  imin[v] = r_nn_i[lpos];
# source_line 1720: 	  imax[v] = r_nx_i[lpos];
# source_line 1721:
# source_line 1722: 	  v++; /* v is MATR_D */
# source_line 1723: 	  jmin[v] = r_dn[rpos];
# source_line 1724: 	  jmax[v] = r_dx[rpos];
# source_line 1725: 	  imin[v] = r_nn_i[lpos];
# source_line 1726: 	  imax[v] = r_nx_i[lpos];
# source_line 1727:
# source_line 1728: 	  v++; /* v is MATR_IR */
# source_line 1729: 	  jmin[v] = r_in[rpos-1];
# source_line 1730: 	  jmax[v] = r_ix[rpos-1];
# source_line 1731: 	  imin[v] = r_nn_i[lpos];
# source_line 1732: 	  imax[v] = r_nx_i[lpos];
# source_line 1733: 	  break;
# source_line 1734:
# source_line 1735: 	case BEGL_nd:
# source_line 1736: 	case BEGR_nd: /* set i and j bands implicitly, except for BEGR_IL, whose i bands are set explicitly based on HMM */
# source_line 1737: 	  v = cm->nodemap[nd]; /* set i and j band for BEG{L,R}_S based on children */
# source_line 1738: 	  imin[v] = jmin[v] = INT_MAX;
# source_line 1739: 	  imax[v] = jmax[v] = INT_MIN;
# source_line 1740: 	  for(y = cm->cfirst[v]; y < cm->cfirst[v]+cm->cnum[v]; y++) {
# source_line 1741: 	    /* if y is reachable, make sure we can get there from v */
# source_line 1742: 	    if(imin[y] != -1) {
# source_line 1743: 	      imin[v] = ESL_MIN(imin[v], imin[y]);
# source_line 1744: 	      imax[v] = ESL_MAX(imax[v], imax[y]);
# source_line 1745: 	    }
# source_line 1746: 	    if(jmin[y] != -1) {
# source_line 1747: 	      jmin[v] = ESL_MIN(jmin[v], jmin[y]);
# source_line 1748: 	      jmax[v] = ESL_MAX(jmax[v], jmax[y]);
# source_line 1749: 	    }
# source_line 1750: 	  }
# source_line 1751: 	  if(imin[v] == INT_MAX) {
# source_line 1752: 	    imin[v] = -1;
# source_line 1753: 	    imax[v] = -2;
# source_line 1754: 	  }
# source_line 1755: 	  if(jmin[v] == INT_MAX) {
# source_line 1756: 	    jmin[v] = -1;
# source_line 1757: 	    jmax[v] = -2;
# source_line 1758: 	  }
# source_line 1759:
# source_line 1760: 	  /* set BEGR_IL's i and j band */
# source_line 1761: 	  if(cm->ndtype[nd] == BEGR_nd) {
# source_line 1762: 	    v++;
# source_line 1763: 	    imin[v] = r_in[lpos-1]; /* BEGR_IL emits before lpos */
# source_line 1764: 	    imax[v] = r_ix[lpos-1];
# source_line 1765: 	    if(imin[v-1] != -1 && imin[v] != -1) { /* if BEGR_S and BEGR_IL is reachable */
# source_line 1766: 	      imin[v-1] = ESL_MIN(imin[v-1], imin[v]); /* expand BEGR_S so it can reach BEGR_IL */
# source_line 1767: 	      jmin[v] = (jmin[v-1] == -1) ? -1 : ESL_MAX(jmin[v-1], i0); /* can't get to a BEGR_IL without emitting at least i0 */
# source_line 1768: 	      jmax[v] = jmax[v-1];
# source_line 1769: 	    }
# source_line 1770: 	    else {
# source_line 1771: 	      imin[v] = jmin[v] = -1;
# source_line 1772: 	      imax[v] = jmax[v] = -2;
# source_line 1773: 	    }
# source_line 1774: 	    esl_stack_IPop(lpos_pda, &lpos); /* pop the remembered lpos from our sister BEGL_nd to use for parent BIF_nd and above */
# source_line 1775: 	  }
# source_line 1776: 	  else { /* BEGL_nd */
# source_line 1777: 	    if ((status = esl_stack_IPush(lpos_pda, lpos)) != eslOK) goto ERROR;
# source_line 1778: 	    lpos = rpos+1; /* next node we pop from stack will be our BEGR sister, on the right, switch lpos to rpos+1 */
# source_line 1779: 	  }
# source_line 1780: 	  break;
# source_line 1781:
# source_line 1782: 	case END_nd:
# source_line 1783: 	  v = cm->nodemap[nd]; /* v is END_E */
# source_line 1784: 	  imin[v] = r_nn_i[lpos];
# source_line 1785: 	  imax[v] = (r_nx_i[lpos] == -2) ? r_nx_i[lpos] : ESL_MIN(r_nx_i[lpos]+1, j0+1); /* +1 is for StateDelta */
# source_line 1786: 	  if(r_in[lpos] != -1) { /* we could come from an IR above us (tricky case) */
# source_line 1787: 	    imin[v] = ESL_MIN(imin[v], ESL_MAX(r_in[lpos] - 1, i0));
# source_line 1788: 	    imax[v] = ESL_MAX(imax[v], ESL_MAX(r_ix[lpos] - 1, i0));
# source_line 1789: 	  }
# source_line 1790: 	  rpos = lpos;
# source_line 1791: 	  if(imin[v] != -1) {
# source_line 1792: 	    jmin[v] = imin[v]-1; /* E must emit d = 0 residues, so j ==i-1 */
# source_line 1793: 	    jmax[v] = imax[v]-1; /* E must emit d = 0 residues, so j ==i-1 */
# source_line 1794: 	  }
# source_line 1795: 	  break;
# source_line 1796:
# source_line 1797: 	case ROOT_nd: /* ROOT is a special case, set i and j bands */
# source_line 1798: 	  /* lpos == 1 and rpos == hmm_M */
# source_line 1799: 	  assert(lpos == 1);
# source_line 1800: 	  assert(rpos == hmm_M);
# source_line 1801: 	  v = cm->nodemap[nd]; /* v is ROOT_S */
# source_line 1802: 	  imin[v] = r_nn_i[1];
# source_line 1803: 	  imax[v] = r_nx_i[1];
# source_line 1804: 	  jmin[v] = r_nn_j[hmm_M];
# source_line 1805: 	  jmax[v] = r_nx_j[hmm_M];
# source_line 1806:
# source_line 1807: 	  v++; /* v is ROOT_IL */
# source_line 1808: 	  imin[v] = r_in[0]; /* ROOT_IL maps to HMM insert state of HMM node 0 */
# source_line 1809: 	  imax[v] = r_ix[0]; /* ROOT_IL maps to HMM insert state of HMM node 0 */
# source_line 1810: 	  /* ROOT_IL's j bands will be same as ROOT_S's, after ensuring state delta of 1 is respected */
# source_line 1811: 	  jmin[v] = (r_nn_j[hmm_M] == -1) ? -1 : ESL_MAX(r_nn_j[hmm_M], i0); /* can't get to ROOT_IL without emitting at least i0 */
# source_line 1812: 	  jmax[v] = r_nx_j[hmm_M];
# source_line 1813: 	  if(r_in[hmm_M] != -1) {
# source_line 1814: 	    jmin[v] = ESL_MIN(jmin[v], r_in[hmm_M]);
# source_line 1815: 	    jmax[v] = ESL_MIN(jmax[v], r_ix[hmm_M]);
# source_line 1816: 	  }
# source_line 1817:
# source_line 1818: 	  v++; /* v is ROOT_IR */
# source_line 1819: 	  if(r_in[hmm_M] != -1) { /* if r_in[hmm_M] == -1, this state is unreachable */
# source_line 1820: 	    imin[v] = r_nn_i[1]; /* HMM state M_0 is silent */
# source_line 1821: 	    imax[v] = r_nx_i[1]; /* HMM state M_0 is silent */
# source_line 1822: 	    if(imin[v-1] != -1) {
# source_line 1823: 	      imin[v] = ESL_MIN(imin[v], imin[v-1]+1);
# source_line 1824: 	      imax[v] = ESL_MAX(imax[v], imax[v-1]+1);
# source_line 1825: 	    }
# source_line 1826: 	    jmin[v] = r_in[hmm_M]; /* ROOT_IR maps to HMM insert state of HMM node hmm_M */
# source_line 1827: 	    jmax[v] = r_ix[hmm_M]; /* ROOT_IR maps to HMM insert state of HMM node hmm_M */
# source_line 1828: 	  }
# source_line 1829: 	  break;
# source_line 1830: 	} /* end of switch(cm->ndtype[nd]) */
# source_line 1831:       } /* end of if(on_right) */
# source_line 1832:
# source_line 1833:       else { /* on left */
# source_line 1834: 	/* set i bands for MATP_nd, MATL_nd only */
# source_line 1835: 	switch(cm->ndtype[nd]) {
# source_line 1836: 	case MATP_nd:
# source_line 1837: 	  lpos = cp9map->nd2lpos[nd];
# source_line 1838: 	  v = cm->nodemap[nd]; /* v is MATP_MP */
# source_line 1839: 	  imin[v] = r_mn[lpos];
# source_line 1840: 	  imax[v] = r_mx[lpos];
# source_line 1841: 	  v++; /* v is MATP_ML */
# source_line 1842: 	  imin[v] = r_mn[lpos];
# source_line 1843: 	  imax[v] = r_mx[lpos];
# source_line 1844: 	  v++; /* v is MATP_MR */
# source_line 1845: 	  imin[v] = r_dn[lpos] == -1 ? -1 : r_dn[lpos]+1;
# source_line 1846: 	  imax[v] = r_dx[lpos] == -2 ? -2 : r_dx[lpos]+1;
# source_line 1847: 	  v++; /* v is MATP_D */
# source_line 1848: 	  imin[v] = r_dn[lpos] == -1 ? -1 : r_dn[lpos]+1;
# source_line 1849: 	  imax[v] = r_dx[lpos] == -2 ? -2 : r_dx[lpos]+1;
# source_line 1850: 	  v++; /* v is MATP_IL */
# source_line 1851: 	  imin[v] = r_in[lpos];
# source_line 1852: 	  imax[v] = r_ix[lpos];
# source_line 1853: 	  /* we deal with setting imin/imax for MATP_IR when we're on the right */
# source_line 1854: 	  break;
# source_line 1855:
# source_line 1856: 	case MATL_nd:
# source_line 1857: 	  lpos = cp9map->nd2lpos[nd];
# source_line 1858: 	  v = cm->nodemap[nd]; /* v is MATL_ML */
# source_line 1859: 	  imin[v] = r_mn[lpos];
# source_line 1860: 	  imax[v] = r_mx[lpos];
# source_line 1861: 	  v++; /* v is MATL_D */
# source_line 1862: 	  imin[v] = r_dn[lpos] == -1 ? -1 : r_dn[lpos]+1;
# source_line 1863: 	  imax[v] = r_dx[lpos] == -2 ? -2 : r_dx[lpos]+1;
# source_line 1864: 	  v++; /* v is MATL_IL */
# source_line 1865: 	  imin[v] = r_in[lpos];
# source_line 1866: 	  imax[v] = r_ix[lpos];
# source_line 1867: 	  break;
# source_line 1868: 	} /* end of switch(cm->ndtype[nd]) */
# source_line 1869:
# source_line 1870: 	if(cm->ndtype[nd] == BIF_nd) {
# source_line 1871: 	  /* push the BIF back on for its right side  */
# source_line 1872: 	  if ((status = esl_stack_IPush(nd_pda, 1)) != eslOK) goto ERROR;
# source_line 1873: 	  if ((status = esl_stack_IPush(nd_pda, nd)) != eslOK) goto ERROR;
# source_line 1874: 	  /* push node index for right child */
# source_line 1875: 	  if ((status = esl_stack_IPush(nd_pda, 0)) != eslOK) goto ERROR;
# source_line 1876: 	  if ((status = esl_stack_IPush(nd_pda, cm->ndidx[cm->cnum[cm->nodemap[nd]]])) != eslOK) goto ERROR;
# source_line 1877: 	  /* push node index for left child */
# source_line 1878: 	  if ((status = esl_stack_IPush(nd_pda, 0)) != eslOK) goto ERROR;
# source_line 1879: 	  if ((status = esl_stack_IPush(nd_pda, cm->ndidx[cm->cfirst[cm->nodemap[nd]]])) != eslOK) goto ERROR;
# source_line 1880: 	}
# source_line 1881: 	else {
# source_line 1882: 	  /* push the node back on for right side */
# source_line 1883: 	  if ((status = esl_stack_IPush(nd_pda, 1)) != eslOK) goto ERROR;
# source_line 1884: 	  if ((status = esl_stack_IPush(nd_pda, nd)) != eslOK) goto ERROR;
# source_line 1885: 	  /* push child node on */
# source_line 1886: 	  if (cm->ndtype[nd] != END_nd) {
# source_line 1887: 	    if ((status = esl_stack_IPush(nd_pda, 0)) != eslOK) goto ERROR;
# source_line 1888: 	    if ((status = esl_stack_IPush(nd_pda, nd+1)) != eslOK) goto ERROR;
# source_line 1889: 	  }
# source_line 1890: 	}
# source_line 1891:       }
# source_line 1892:     }
# source_line 1893:
# source_line 1894:   /* If we're allowing truncated alignments, do a final pass through all states, expanding bands to allow for
# source_line 1895:    * L and/or R and/or T marginal alignments, as necessary,
# source_line 1896:    * cp9b->{L,R}marg_{i,j}{min,max} were defined in cp9_PredictStartAndEndPositions().
# source_line 1897:    */
# source_line 1898:   if(do_trunc) {
# source_line 1899:     for(v = 0; v < cm->M; v++) {
# source_line 1900:       if(cp9b->Lvalid[v] || cp9b->Tvalid[v]) { /* allow for left marginal alignment by expanding j band */
# source_line 1901: 	jmin[v] = (jmin[v] == -1) ? cp9b->Lmarg_jmin : ESL_MIN(jmin[v], cp9b->Lmarg_jmin);
# source_line 1902: 	jmax[v] = (jmax[v] == -2) ? cp9b->Lmarg_jmax : ESL_MAX(jmax[v], cp9b->Lmarg_jmax);
# source_line 1903:       }
# source_line 1904:       if(cp9b->Rvalid[v] || cp9b->Tvalid[v]) { /* allow for right marginal alignment by expanding i band */
# source_line 1905: 	imin[v] = (imin[v] == -1) ? cp9b->Rmarg_imin : ESL_MIN(imin[v], cp9b->Rmarg_imin);
# source_line 1906: 	imax[v] = (imax[v] == -2) ? cp9b->Rmarg_imax : ESL_MAX(imax[v], cp9b->Rmarg_imax);
# source_line 1907:       }
# source_line 1908:     }
# source_line 1909:   }
# source_line 1910:
# source_line 1911:   if(! doing_search) { /* if we're aligning the full seq must be aligned at the root state */
# source_line 1912:     imin[0] = i0;                   /* first residue must be in subtree of ROOT_S */
# source_line 1913:     if(imin[1] != -1) imin[1] = i0; /* first residue must be in subtree of ROOT_IL, if it is used */
# source_line 1914:     jmax[0] = j0;                   /* final residue must be in subtree of ROOT_S */
# source_line 1915:     if(jmin[1] != -1) jmax[1] = j0; /* final residue must be in subtree of ROOT_IL if it is used */
# source_line 1916:     if(jmin[2] != -1) jmax[2] = j0; /* final residue must be in subtree of ROOT_IR if it is used */
# source_line 1917:   }
# source_line 1918:
# source_line 1919:   /* Final pass through all states:
# source_line 1920:    * 1. if any band value implies a state is unreachable, make it so by setting imin[v]=jmin[v]=-1, imax[v]=jmax[v]=-2;
# source_line 1921:    * 2. set detached inserts unreachable.
# source_line 1922:    * 3. if(!do_trunc) for left emitters enforce jmin/jmax allow at least 1 residue to be emitted
# source_line 1923:    * 4. if(!do_trunc) for MP states, enforce jmin/jmax allow at least 2 residues to be emitted
# source_line 1924:    */
# source_line 1925:   for(v = 0; v < cm->M; v++) {
# source_line 1926:     ESL_DASSERT1(((imin[v] == -1 && imax[v] == -2) || (imin[v] >= 0 && imax[v] >= 0)));
# source_line 1927:     ESL_DASSERT1(((jmin[v] == -1 && jmax[v] == -2) || (jmin[v] >= 0 && jmax[v] >= 0)));
# source_line 1928:     if(imin[v] == -1 || jmin[v] == -1) {
# source_line 1929:       imin[v] = jmin[v] = -1;
# source_line 1930:       imax[v] = jmax[v] = -2;
# source_line 1931:     }
# source_line 1932:     if(StateIsDetached(cm, v)) {
# source_line 1933:       imin[v] = jmin[v] = -1;
# source_line 1934:       imax[v] = jmax[v] = -2;
# source_line 1935:     }
# source_line 1936:     if(! do_trunc) {
# source_line 1937:       if(cm->sttype[v] == MP_st) {
# source_line 1938: 	if(jmax[v] == i0) { /* HMM tells us right half of MP state must emit first residue in the sequence, we know better, make state unreachable */
# source_line 1939: 	  ESL_DASSERT1((jmin[v] == i0));
# source_line 1940: 	  imin[v] = jmin[v] = -1; /* ignore hmm */
# source_line 1941: 	  imax[v] = jmax[v] = -2; /* ignore hmm */
# source_line 1942: 	}
# source_line 1943: 	else if (jmin[v] == i0) { /* HMM tells us right half of MP state could possibly first residue (i0), but we know it can't (see comment above). */
# source_line 1944: 	  jmin[v]++;              /* pad 1 onto what the hmm thought, make first emittable residue i0+1 */
# source_line 1945: 	  /* leave jmax[v] alone, we konw it's not == i0, we checked for that case above */
# source_line 1946: 	}
# source_line 1947:       }
# source_line 1948:       /* if a left emitter, enforce jmin/jmax require at least 1 residue is emitted */
# source_line 1949:       if((StateLeftDelta(cm->sttype[v]) == 1) && imin[v] != -1) {
# source_line 1950: 	if(jmax[v] == (i0-1)) { /* HMM bands implied state must be entered after emitting exactly 0 residues, we know better, make it unreachable */
# source_line 1951: 	  ESL_DASSERT1((jmin[v] == (i0-1)));
# source_line 1952: 	  imin[v] = jmin[v] = -1; /* ignore hmm */
# source_line 1953: 	  imax[v] = jmax[v] = -2; /* ignore hmm */
# source_line 1954: 	}
# source_line 1955: 	else if (jmin[v] == (i0-1)) {
# source_line 1956: 	  jmin[v] = i0; /* pad 1 onto what the hmm thought */
# source_line 1957: 	  /* leave jmax[v] alone, we know it's not == i0-1, we checked for that case above */
# source_line 1958: 	}
# source_line 1959:       }
# source_line 1960:     }
# source_line 1961:   }
# source_line 1962:
# source_line 1963:
# source_line 1964: # 1973 "hmmband.c"
# source_line 1965:
# source_line 1966:   /* A final, brutal hack. If the hmm used to derive bands has local
# source_line 1967:    * begins, ends and ELs on, it's possible (but extremely rare
# source_line 1968:    * empirically, even with very high tau values (0.49!)) that no
# source_line 1969:    * valid CM parse exists within the i and j bands. To avoid this, if
# source_line 1970:    * the CM has local begins and ends on then we use a brutal hack
# source_line 1971:    * here to enable at least one valid parse from the ROOT_S to a
# source_line 1972:    * state from which the EL can be reached and able to emit all
# source_line 1973:    * residues.
# source_line 1974:    *
# source_line 1975:    * There's 2 relevant cases.
# source_line 1976:    *
# source_line 1977:    * Case 1: node 1 is a MATP, MATR, or MATL node (this is the easier case)
# source_line 1978:    * Case 2: node 1 is a BIF node
# source_line 1979:    *
# source_line 1980:    * Case 1: node 1 is a MATP, MATR, or MATL node (this is the easier case)
# source_line 1981:    * A. assert CM local begins and ends are on (they should be if we're using a localized HMM to get bands).
# source_line 1982:    *    and we can do a local begin into and a local end out of node 1. This will be TRUE unless there
# source_line 1983:    *    are only 3 nodes in the CM (which is impossible, cmbuild won't build a 3 node CM - the reason is that
# source_line 1984:    *    such a CM would suck at local alignment b/c no local ends are possible (not to mention they're too small
# source_line 1985:    *    to be useful, and that if node 1 == MATL the CM can only emit/align 1 residue in local mode b/c the
# source_line 1986:    *    ROOT_IL, ROOT_IR are unreachable and the MATL_IL is detached!).
# source_line 1987:    *
# source_line 1988:    * B. if we're doing alignment (full target must be accounted for):
# source_line 1989:    *    v = cm->nodemap[nd]
# source_line 1990:    *    set imin[v] = ESL_MIN(imin[v], i0)
# source_line 1991:    *        imax[v] = ESL_MAX(imax[v], i0)
# source_line 1992:    *        jmin[v] = ESL_MIN(jmin[v], j0)
# source_line 1993:    *        jmax[v] = ESL_MAX(jmax[v], j0)
# source_line 1994:    *    else if we're doing search and v is unreachable, make it reachable by setting
# source_line 1995:    *        imin[v] = imin[0];
# source_line 1996:    *        imax[v] = imax[0];
# source_line 1997:    *        jmin[v] = jmin[0];
# source_line 1998:    *        jmax[v] = jmax[0];
# source_line 1999:    *    then we'll be able to emit some residues from v, (so we're guaranteed a valid parse.)
# source_line 2000:    *
# source_line 2001:    * Case 2: node 1 is a BIF node
# source_line 2002:    * v = cm->nodemap[nd] (the BIF_B state)
# source_line 2003:    * if v is reachable and we're doing alignment, expand it's bands so that it can
# source_line 2004:    * account for the full seq:
# source_line 2005:    *    set imin[v] = ESL_MIN(imin[v], i0)
# source_line 2006:    *        imax[v] = ESL_MAX(imax[v], i0)
# source_line 2007:    *        jmin[v] = ESL_MIN(jmin[v], j0)
# source_line 2008:    *        jmax[v] = ESL_MAX(jmax[v], j0)
# source_line 2009:    * else if v is reachable and we're doing search, ensure that one contiguous chunk of
# source_line 2010:    * seq can be emitted by BIF's children (see code)
# source_line 2011:    *
# source_line 2012:    * if v is not reachable (if we're doing search or not), we enforce 1 valid parse,
# source_line 2013:    * the BIF must emit the full target, residues i0..j0-1 from its' BEGL_S's EL state, and
# source_line 2014:    * residue j0 from it's BEGR_S EL state.
# source_line 2015:    */
# source_line 2016:   if(hmm_is_localized && cm_is_fully_localized) {
# source_line 2017:     if(do_trunc) cp9b->Jvalid[0] = TRUE;
# source_line 2018:     if(imin[0] == -1) { /* ROOT_S is unreachable, uhh... */
# source_line 2019:       imin[0] = imax[0] = i0;
# source_line 2020:       jmin[0] = jmax[0] = j0;
# source_line 2021:     }
# source_line 2022:     if(cm->nodes == 3) ESL_FAIL(eslEINCONCEIVABLE, errbuf, "cp9_HMM2ijBands(), cm/hmm are locally configured, only 3 nodes in the CM, this is an illegal CM b/c local ENDs are impossible.");
# source_line 2023:     nd = 1;
# source_line 2024:     if(i0 == j0) {
# source_line 2025:       while((nd < cm->nodes) && (cm->ndtype[nd] == MATP_nd)) nd++; /* a local begin into a MATP_MP state can't happen when the target is 1 residue, it must emit 2 residues */
# source_line 2026:       if(cm->ndtype[nd] == END_nd) ESL_FAIL(eslEINCONCEIVABLE, errbuf, "cp9_HMM2ijBands(), CM has no MATL, MATR or BIF nodes, this shouldn't happen (cmbuild forbids it)!\n");
# source_line 2027:     }
# source_line 2028:     if(cm->ndtype[nd] == BIF_nd) {
# source_line 2029:       v = cm->nodemap[nd];
# source_line 2030:       w = cm->cfirst[v]; /* BEGL_S */
# source_line 2031:       y = cm->cnum[v];   /* BEGR_S */
# source_line 2032:       if(do_trunc) {
# source_line 2033: 	cp9b->Jvalid[v] = TRUE;
# source_line 2034: 	cp9b->Jvalid[w] = TRUE;
# source_line 2035: 	cp9b->Jvalid[y] = TRUE;
# source_line 2036:       }
# source_line 2037:       if(imin[v] != -1 && imin[w] != -1 && imin[y] != -1) { /* v and its children w and y are all reachable */
# source_line 2038: 	if(!doing_search) { /* we need to be able to account for the full sequence */
# source_line 2039: 	  imin[v] = ESL_MIN(imin[v], i0);
# source_line 2040: 	  imax[v] = ESL_MAX(imax[v], i0);
# source_line 2041: 	  jmin[v] = ESL_MIN(jmin[v], j0);
# source_line 2042: 	  jmax[v] = ESL_MAX(jmax[v], j0);
# source_line 2043: 	  imin[w] = imin[v];
# source_line 2044: 	  imax[w] = imax[v];
# source_line 2045: 	  jmax[w] = ESL_MAX(jmax[w], ESL_MIN(j0, imax[w]));
# source_line 2046: 	  jmin[y] = jmin[v];
# source_line 2047: 	  jmax[y] = jmax[v];
# source_line 2048: 	  imin[y] = ESL_MIN(imin[y], ESL_MAX(i0, jmin[y]));
# source_line 2049: 	  /* now ensure that imin[y] <= jmax[w]+1, so we can definitely emit the full seq */
# source_line 2050: 	  imin[y] = ESL_MIN(imin[y], ESL_MAX(i0, jmax[w]+1));
# source_line 2051: 	  imax[y] = ESL_MAX(imin[y], imax[y]);
# source_line 2052: 	}
# source_line 2053: 	else { /* doing search, we only need to be able to emit some range of residues from BEGL and BEGR's EL states */
# source_line 2054: 	  imin[y] = ESL_MIN(imin[y], ESL_MAX(i0, jmax[w]+1));
# source_line 2055: 	  imax[y] = ESL_MAX(imin[y], imax[y]);
# source_line 2056: 	}
# source_line 2057:       } /* end of if(imin[v] != -1) */
# source_line 2058:       else { /* v, w or y are unreachable, make them reachable */
# source_line 2059: 	if(! doing_search) {
# source_line 2060: 	  /* if we're doing alignment, we enforce that the full seq must be emittable
# source_line 2061: 	   * by BIF and it's children's (BEGL_S and BEGR_S) EL states */
# source_line 2062: 	  imin[v] = i0;
# source_line 2063: 	  imax[v] = i0;
# source_line 2064: 	  jmin[v] = j0;
# source_line 2065: 	  jmax[v] = j0;
# source_line 2066: 	  imin[w] = i0; /* w will emit i0..j0-1 (which may be 0 residues if i0==j0) */
# source_line 2067: 	  imax[w] = i0;
# source_line 2068: 	  jmin[w] = j0-1;
# source_line 2069: 	  jmax[w] = j0-1;
# source_line 2070: 	  imin[y] = j0; /* y will emit only j0 */
# source_line 2071: 	  imax[y] = j0;
# source_line 2072: 	  jmin[y] = j0;
# source_line 2073: 	  jmax[y] = j0;
# source_line 2074: 	}
# source_line 2075: 	else {
# source_line 2076: 	  /* if we're doing search we enforce that the residues from imin[0]..jmax[0] are emittable
# source_line 2077: 	   * by BIF and it's children's (BEGL_S and BEGR_S) EL states */
# source_line 2078: 	  imin[v] = imin[0];
# source_line 2079: 	  imax[v] = imin[0];
# source_line 2080: 	  jmin[v] = jmax[0];
# source_line 2081: 	  jmax[v] = jmax[0];
# source_line 2082: 	  imin[w] = imin[0]; /* w will emit imin[0]..jmax[0]-1 (which may be 0 residues if imin[0]==jmax[0]) */
# source_line 2083: 	  imax[w] = imin[0];
# source_line 2084: 	  jmin[w] = jmax[0]-1;
# source_line 2085: 	  jmax[w] = jmax[0]-1;
# source_line 2086: 	  imin[y] = jmax[0]; /* y will emit only jmax[0] */
# source_line 2087: 	  imax[y] = jmax[0]; /* y will emit only jmax[0] */
# source_line 2088: 	  jmin[y] = jmax[0];
# source_line 2089: 	  jmax[y] = jmax[0];
# source_line 2090: 	}
# source_line 2091:       }
# source_line 2092:     } /* end of if(cm->ndtype[nd] == BIF_nd) */
# source_line 2093:     else {
# source_line 2094:       /* node nd is a MATL, MATR or MATP */
# source_line 2095:       ESL_DASSERT1((cm->ndtype[nd] == MATL_nd || cm->ndtype[nd] == MATP_nd || cm->ndtype[nd] == MATR_nd));
# source_line 2096:       assert(cm->ndtype[nd] == MATL_nd || cm->ndtype[nd] == MATP_nd || cm->ndtype[nd] == MATR_nd);
# source_line 2097:       v = cm->nodemap[nd];
# source_line 2098:       if(do_trunc) cp9b->Jvalid[v] = TRUE;
# source_line 2099:       /* we can do a local begin into and local end out of v */
# source_line 2100:       ESL_DASSERT1((NOT_IMPOSSIBLE(cm->beginsc[v])));
# source_line 2101:       ESL_DASSERT1((NOT_IMPOSSIBLE(cm->endsc[v])));
# source_line 2102:       assert(NOT_IMPOSSIBLE(cm->beginsc[v]));
# source_line 2103:       assert(NOT_IMPOSSIBLE(cm->endsc[v]));
# source_line 2104:       if(!doing_search) { /* we need to be able to account for the full sequence */
# source_line 2105: 	if(imin[v] == -1) { /* v is unreachable, make it reachable only for emitting the full seq */
# source_line 2106: 	  imin[v] = imax[v] = i0;
# source_line 2107: 	  jmin[v] = jmax[v] = j0;
# source_line 2108: 	}
# source_line 2109: 	else { /* v is reachable, expand it's band so it can emit the full seq */
# source_line 2110: 	  imin[v] = ESL_MIN(imin[v], i0);
# source_line 2111: 	  imax[v] = ESL_MAX(imax[v], i0);
# source_line 2112: 	  jmin[v] = ESL_MIN(jmin[v], j0);
# source_line 2113: 	  jmax[v] = ESL_MAX(jmax[v], j0);
# source_line 2114: 	}
# source_line 2115:       }
# source_line 2116:       else { /* doing search, do not need to account for full target sequence, make it so we can reach v for some i and j (this will guarantee >= 1 valid parse) */
# source_line 2117: 	if(imin[v] == -1) { /* v is unreachable */
# source_line 2118: 	  imin[v] = imin[0];
# source_line 2119: 	  imax[v] = imax[0];
# source_line 2120: 	  jmin[v] = jmin[0];
# source_line 2121: 	  jmax[v] = jmax[0];
# source_line 2122: 	}
# source_line 2123: 	else { /* v is reachable, make sure it's reachable from the ROOT_S state, expand the ROOT_S band */
# source_line 2124: 	  imin[0] = ESL_MIN(imin[0], imin[v]);
# source_line 2125: 	  imax[0] = ESL_MAX(imax[0], imax[v]);
# source_line 2126: 	  jmin[0] = ESL_MIN(jmin[0], jmin[v]);
# source_line 2127: 	  jmax[0] = ESL_MAX(jmax[0], jmax[v]);
# source_line 2128: 	}
# source_line 2129:       }
# source_line 2130:     }
# source_line 2131:   }
# source_line 2132:   /* end of brutal hack */
# source_line 2133:
# source_line 2134:
# source_line 2135:
# source_line 2136:
# source_line 2137:
# source_line 2138:   esl_stack_Destroy(nd_pda);
# source_line 2139:   esl_stack_Destroy(lpos_pda);
# source_line 2140:   free(r_mn);
# source_line 2141:   free(r_mx);
# source_line 2142:   free(r_dn);
# source_line 2143:   free(r_dx);
# source_line 2144:   free(r_in);
# source_line 2145:   free(r_ix);
# source_line 2146:   free(r_nn_i);
# source_line 2147:   free(r_nx_i);
# source_line 2148:   free(r_nn_j);
# source_line 2149:   free(r_nx_j);
# source_line 2150:
# source_line 2151:   return eslOK;
# source_line 2152:
# source_line 2153:  ERROR:
# source_line 2154:   ESL_FAIL(status, errbuf, "Memory allocation error.\n");
# source_line 2155: }
# source_line 2156:

# %%
print("Binary code address to source code line mapping:")
for k, v in addr_to_source_code_file_line['mapping'].items():
    print(f"binary address {hex(k)}: source line {v[1]}")
# Out:
# Binary code address to source code line mapping:
# binary address 0xa4688: source line 1521
# binary address 0xa468b: source line 1521
# binary address 0xa4690: source line 1521
# binary address 0xa4694: source line 1521
# binary address 0xa4698: source line 1570
# binary address 0xa469b: source line 1570
# binary address 0xa46a1: source line 1571
# binary address 0xa46a4: source line 1571
# binary address 0xa46f8: source line 1571
# binary address 0xa46fb: source line 1571
# binary address 0xa4702: source line 1571
# binary address 0xa4705: source line 1571
# binary address 0xa4707: source line 1571
# binary address 0xa470c: source line 1571
# binary address 0xa46a6: source line 1572
# binary address 0xa46a9: source line 1572
# binary address 0xa4710: source line 1572
# binary address 0xa4713: source line 1572
# binary address 0xa471a: source line 1572
# binary address 0xa471d: source line 1572
# binary address 0xa471f: source line 1572
# binary address 0xa4724: source line 1572
# binary address 0xa46ab: source line 1573
# binary address 0xa46ae: source line 1573
# binary address 0xa46b4: source line 1573
# binary address 0xa46d0: source line 1573
# binary address 0xa46d3: source line 1573
# binary address 0xa46d6: source line 1573
# binary address 0xa46dd: source line 1573
# binary address 0xa46e0: source line 1573
# binary address 0xa46e2: source line 1573
# binary address 0xa4730: source line 1570
# binary address 0xa4737: source line 1570
# binary address 0xa473a: source line 1570
# binary address 0xa473c: source line 1570
# binary address 0xa4741: source line 1570
# binary address 0xa46b7: source line 1573
# binary address 0xa46bb: source line 1573
